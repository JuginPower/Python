# %%
import sqlite3

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# fig, ax = plt.subplots()
plt.scatter([1,2,3,4], [5,6,7,8], label='First Avenger', marker='x')
plt.scatter([1,2,3,4], [4,5,6,7], label='Second Avenger', marker='o')
plt.title('Avengers')
plt.legend()
plt.show()

# %%
path_db = "C:/Users/kraft/Desktop/meine_Programme/Python/Anaconda/Workstation/finanzmarkt/indices/Indizes.db"

# %%
conn = sqlite3.connect(path_db)
curs = conn.cursor()

# %%
sql = 'select * from reversales'
df_r = pd.read_sql(sql, conn)

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Point   2035 non-null   int64
#  1   Scale   2035 non-null   float64
#  2   Symbol  2035 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 47.8+ KB

# %%
df_r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       470 non-null    object
#  1   Direction  470 non-null    object
#  2   Symbol     470 non-null    object
# dtypes: object(3)
# memory usage: 11.1+ KB

# %%
print(df_r.to_string())
# Out:
#            Date Direction     Symbol
# 0    2000-01-17        up        DAX
# 1    2000-04-05      down        DAX
# 2    2001-04-12        up        DAX
# 3    2001-07-25      down        DAX
# 4    2001-10-03        up        DAX
# 5    2002-05-30      down        DAX
# 6    2002-10-21        up        DAX
# 7    2003-02-07      down        DAX
# 8    2003-05-05        up        DAX
# 9    2006-06-08      down        DAX
# 10   2006-09-29        up        DAX
# 11   2007-08-10      down        DAX
# 12   2007-10-05        up        DAX
# 13   2008-01-18      down        DAX
# 14   2008-04-07        up        DAX
# 15   2008-06-20      down        DAX
# 16   2008-11-03        up        DAX
# 17   2008-11-17      down        DAX
# 18   2008-12-10        up        DAX
# 19   2009-01-15      down        DAX
# 20   2009-04-09        up        DAX
# 21   2011-03-15      down        DAX
# 22   2011-04-06        up        DAX
# 23   2011-08-02      down        DAX
# ...
